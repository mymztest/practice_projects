# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
read_dtl_source_path = "abfss://bronze@adwstorage1datalake.dfs.core.windows.net/"

read_adv_caledner_path = read_dtl_source_path + 'AdventureWorks_Calendar'
read_adv_cust_path = read_dtl_source_path + 'AdventureWorks_Customers'
read_adv_p_cat_path = read_dtl_source_path + 'AdventureWorks_Product_Categories'
read_adv_p_sub_cat_path = read_dtl_source_path + 'AdventureWorks_Product_Subcategories'
read_adv_prod_path = read_dtl_source_path + 'AdventureWorks_Products'
read_adv_ret_path = read_dtl_source_path + 'AdventureWorks_Returns'
read_adv_sale_2015_path = read_dtl_source_path + 'AdventureWorks_Sales_2015'
read_adv_sale_2016_path = read_dtl_source_path + 'AdventureWorks_Sales_2016'
read_adv_sale_2017_path = read_dtl_source_path + 'AdventureWorks_Sales_2017'
read_adv_tr_path = read_dtl_source_path + 'AdventureWorks_Territories'

# %%
#df_cust = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Customers")
df_cust = spark.read.csv(path=read_adv_cust_path,header=True, inferSchema=True)
df_cust.display()

# %%
#df_cal = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Calendar")
#df_cal = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(folder_path)
df_cal = spark.read.csv(path=read_adv_caledner_path,header=True, inferSchema=True)
df_cal.head()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_p_cat = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Product_Categories")
df_p_cat = spark.read.csv(path=read_adv_p_cat_path,header=True, inferSchema=True)
df_p_cat.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductCategoryKey</th><th>CategoryName</th></tr></thead><tbody><tr><td>1</td><td>Bikes</td></tr><tr><td>2</td><td>Components</td></tr><tr><td>3</td><td>Clothing</td></tr><tr><td>4</td><td>Accessories</td></tr></tbody></table></div>

# %%
#df_p_sub_cat = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Product_Subcategories")
df_p_sub_cat = spark.read.csv(path=read_adv_p_sub_cat_path,header=True, inferSchema=True)
df_p_sub_cat.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_prod = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Products")
df_prod = spark.read.csv(path=read_adv_prod_path,header=True, inferSchema=True)
df_prod.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_ret = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Returns")
df_ret = spark.read.csv(path=read_adv_ret_path,header=True, inferSchema=True)
df_ret.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_sale_2015 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Sales_2015")
df_sale_2015 = spark.read.csv(path=read_adv_sale_2015_path,header=True, inferSchema=True)

df_sale_2015.display()

# %%
#df_sale_2016 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Sales_2016")
df_sale_2016 = spark.read.csv(path=read_adv_sale_2016_path,header=True, inferSchema=True)
df_sale_2016.display()

# %%
#df_sale_2017 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Sales_2017")
df_sale_2017 = spark.read.csv(path=read_adv_sale_2017_path,header=True, inferSchema=True)
df_sale_2017.display()

# %%
#df_Tr = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://bronze@adwstorage1datalake.dfs.core.windows.net/AdventureWorks_Territories")
df_Tr = spark.read.csv(path=read_adv_tr_path,header=True, inferSchema=True)
df_Tr.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
